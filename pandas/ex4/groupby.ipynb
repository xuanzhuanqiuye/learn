# %%
import pandas as pd

# %%
df=pd.read_excel("test.xls")

# %%
df
# Out:
#                物料编码              物料名称          仓库名称            仓库编码 库存主单位  \
# 0   101.01.00005-00         十字槽沉头自攻螺钉  吉林长春九台办事处良品仓  21.72.10.06-01   Pcs
# 1   102.01.01058-00                轴承  吉林长春九台办事处良品仓  21.72.10.06-01   Pcs
# 2   102.07.01038-00              联级带轮  吉林长春九台办事处良品仓  21.72.10.06-01   Pcs
# 3   102.27.03876-00               电子线  吉林长春九台办事处良品仓  21.72.10.06-01   Pcs
# 4   102.27.03876-00               电子线  吉林长春九台办事处良品仓  21.72.10.06-01   Pcs
# 5   102.27.05534-00             数据传输线  吉林长春九台办事处良品仓  21.72.10.06-01   Pcs
# 6   102.31.01023-00              滚珠导轨  吉林长春九台办事处良品仓  21.72.10.06-01   Pcs
# 7   103.15.01071-00    两层PCBA板_07USBI  吉林长春九台办事处良品仓  21.72.10.06-01   Pcs
# 8   106.08.01251-01       钞门_0606接客钞门  吉林长春九台办事处良品仓  21.72.10.06-01   Pcs
# 9   106.08.03017-00               调节片  吉林长春九台办事处良品仓  21.72.10.06-01   Pcs
# 10  106.14.01302-00  堆钞缓冲块_08接客钞门缓冲胶条  吉林长春九台办事处良品仓  21.72.10.06-01   Pcs
# 11  106.15.01278-01   盖板_YH09大额通道后部盖板  吉林长春九台办事处良品仓  21.72.10.06-01   Pcs
# ...

# %%
df1=df.apply(lambda x:(x['库存数量']-1),axis=1)

# %%
df1
# Out:
# 0     15
# 1      7
# 2      1
# 3      2
# 4      1
# 5      1
# 6      1
# 7      1
# 8      3
# 9      0
# 10     7
# 11     1
# 12    12
# 13     7
# 14     2
# 15     0
# dtype: int64

# %%
type(df['库存数量'])
# Out:
# pandas.core.series.Series

# %%
df['库存主单位'].lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_9572/3982575915.py in <module>
# ----> 1 df['库存主单位'].lower()
#
# d:\pycharmprojects\pythonproject\learn\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'lower'
